# %%
import geopandas as gpd
from shapely.geometry import shape

# %%
stations = pd.read_csv('../data/stations.csv')
stations['geometry'] = stations.apply(lambda z: Point(z.X, z.Y), axis=1)
stations = gp.GeoDataFrame(stations)

# %%
data = gpd.pd.read_csv('./data/dataframe.csv')

# %%
geoms = list(data.geometry)

# %%
shape(','.join(geoms[0].split(' ')[:2]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-42c69b6f879a> in <module>
# ----> 1 shape(','.join(geoms[0].split(' ')[:2]))
#
# ~\AppData\Local\Continuum\anaconda3\envs\gis\lib\site-packages\shapely\geometry\geo.py in shape(context)
#      27     else:
#      28         ob = context
# ---> 29     geom_type = ob.get("type").lower()
#      30     if geom_type == "point":
#      31         return Point(ob["coordinates"])
#
# AttributeError: 'str' object has no attribute 'get'

# %%
gdf

# %%
data = gpd.pd.read_csv('./data/dataframe.csv')
gdf = gpd.GeoDataFrame(data=data.drop('geometry', axis=1), geometry=data.geometry, crs={'init':'epsg:32608'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-9919f9e09673> in <module>
#       1 data = gpd.pd.read_csv('./data/dataframe.csv')
# ----> 2 gdf = gpd.GeoDataFrame(data=data.drop('geometry', axis=1), geometry=data.geometry, crs={'init':'epsg:32608'})
#
# ~\AppData\Local\Continuum\anaconda3\envs\gis\lib\site-packages\geopandas\geodataframe.py in __init__(self, *args, **kwargs)
#      47         self.crs = crs
#      48         if geometry is not None:
# ---> 49             self.set_geometry(geometry, inplace=True)
#      50         self._invalidate_sindex()
#      51
#
# ~\AppData\Local\Continuum\anaconda3\envs\gis\lib\site-packages\geopandas\geodataframe.py in set_geometry(self, col, drop, inplace, crs)
#     146         # Check that we are using a listlike of geometries
# ...

# %%
gdf
# Out:
#        Unnamed: 0  snow_depth  dem_value  vegheight_max  \
# 0               0    0.597172  81.355360       3.573110
# 1               1    0.684059  81.976460       2.056134
# 2               2    0.628670  83.358240       0.402279
# 3               3    0.609438  85.348495       0.402279
# 4               4    0.626953  87.463200       0.399229
# 5               5    0.583382  89.312380       0.392668
# 6               6    0.524840  90.682660       0.341354
# 7               7    0.481599  91.160570       0.448507
# 8               8    0.524630  90.345924       0.793439
# 9               9    0.658077  88.356155       1.776165
# 10             10    0.725905  86.676880       2.704126
# 11             11    0.774966  86.190636       2.704126
# 12             12    0.715822  86.490944       1.781071
# 13             13    0.733486  87.213330       1.272209
# 14             14    0.673725  89.425340       1.138058
# 15             15    0.661117  92.788246       0.796140
# ...
